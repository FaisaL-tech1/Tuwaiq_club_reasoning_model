# %% [markdown]
# # Whiteboard
#
# Notes and scratch work for this chapter.

# %%
from importlib.metadata import version

used_libraries = [
    "reasoning_from_scratch",
    "torch",
    "tokenizers"  # Used by reasoning_from_scratch
]

for lib in used_libraries:
    print(f"{lib} version: {version(lib)}")
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\metadata\__init__.py:397, in Distribution.from_name(cls, name)
#     396 try:
# --> 397     return next(cls.discover(name=name))
#     398 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[22], line 10
#       6     "tokenizers"  # Used by reasoning_from_scratch
#       7 ]
#       8
#       9 for lib in used_libraries:
# ---> 10     print(f"{lib} version: {version(lib)}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\metadata\__init__.py:889, in version(distribution_name)
#     882 def version(distribution_name):
#     883     """Get the version string for the named package.
#     884
# ...
